# %% [markdown]
# # Fuzzy match on address data

# %% [markdown]
# The project is to do a fuzzy match on two address files
#
#
# **Address match process:**
#
# - 1: Data preprocess
#
#    - Capitalize string
#
#    - Remove punctuation
#
#    - Split street address into street number and street name
#
#
# - 2: Data match
#
#    - Matched data if same city name
#
#    - Do Fuzzy match on street name and filter the result with highest score
#
#    - Filter the result if street number is same
#
#
# - 3:Non_mathed data check
#
#    - Manual check the non_matched data in data source and find the reasons
#
# Let's get started!

# %% [markdown]
# ## Reference
#
# - Data link:   https://dedupe.io/tutorial/merging-and-matching-multiple-datasets.html
#
#
# - Compare time on remove punctuation : https://stackoverflow.com/questions/265960/best-way-to-strip-punctuation-from-a-string

# %% [markdown]
# ## 1: Data import

# %%
import numpy as np
import pandas as pd

# %%
resturant=pd.read_csv("/Users/admin/Desktop/Address_macth/restaurant-1.csv")
data=pd.read_csv("/Users/admin/Desktop/Address_macth/restaurant-2.csv")

# %%
resturant.head()
# Out:
#                         name                     address             city  \
# 0  arnie morton's of chicago   "435 s. la cienega blvd."    "los angeles"
# 1                 art's deli       "12224 ventura blvd."    "studio city"
# 2              bel-air hotel      "701 stone canyon rd."        "bel air"
# 3                 cafe bizou       "14016 ventura blvd."   "sherman oaks"
# 4                  campanile       "624 s. la brea ave."    "los angeles"
#
#             cuisine unique_id
# 0     "steakhouses"       '0'
# 1           "delis"       '1'
# 2     "californian"       '2'
# 3   "french bistro"       '3'
# 4     "californian"       '4'

# %%
data.head()
# Out:
#                       name_2                  address_2           city_2  \
# 0  arnie morton's of chicago   "435 s. la cienega blv."    "los angeles"
# 1         art's delicatessen      "12224 ventura blvd."    "studio city"
# 2              hotel bel-air     "701 stone canyon rd."        "bel air"
# 3                 cafe bizou      "14016 ventura blvd."   "sherman oaks"
# 4                  campanile      "624 s. la brea ave."    "los angeles"
#
#         cuisine_2 unique_id
# 0      "american"       '0'
# 1      "american"       '1'
# 2   "californian"       '2'
# 3        "french"       '3'
# 4      "american"       '4'

# %% [markdown]
# ## 2. Data preprocess
#
# ### 2.1 Capitalize address
#
# - Use str.upper() to capitalize data

# %%
resturant=resturant.apply(lambda x: x.str.upper())
resturant.head()
# Out:
#                         name                     address             city  \
# 0  ARNIE MORTON'S OF CHICAGO   "435 S. LA CIENEGA BLVD."    "LOS ANGELES"
# 1                 ART'S DELI       "12224 VENTURA BLVD."    "STUDIO CITY"
# 2              BEL-AIR HOTEL      "701 STONE CANYON RD."        "BEL AIR"
# 3                 CAFE BIZOU       "14016 VENTURA BLVD."   "SHERMAN OAKS"
# 4                  CAMPANILE       "624 S. LA BREA AVE."    "LOS ANGELES"
#
#             cuisine unique_id
# 0     "STEAKHOUSES"       '0'
# 1           "DELIS"       '1'
# 2     "CALIFORNIAN"       '2'
# 3   "FRENCH BISTRO"       '3'
# 4     "CALIFORNIAN"       '4'

# %%
data=data.apply(lambda x: x.str.upper())
data.head()
# Out:
#                       name_2                  address_2           city_2  \
# 0  ARNIE MORTON'S OF CHICAGO   "435 S. LA CIENEGA BLV."    "LOS ANGELES"
# 1         ART'S DELICATESSEN      "12224 VENTURA BLVD."    "STUDIO CITY"
# 2              HOTEL BEL-AIR     "701 STONE CANYON RD."        "BEL AIR"
# 3                 CAFE BIZOU      "14016 VENTURA BLVD."   "SHERMAN OAKS"
# 4                  CAMPANILE      "624 S. LA BREA AVE."    "LOS ANGELES"
#
#         cuisine_2 unique_id
# 0      "AMERICAN"       '0'
# 1      "AMERICAN"       '1'
# 2   "CALIFORNIAN"       '2'
# 3        "FRENCH"       '3'
# 4      "AMERICAN"       '4'

# %% [markdown]
# ### 2.2 Remove punctuation
#
# - str.translate(str.maketrans(A,B,C)): copy the string and replace A to B from the maketrans table and delete C;
#
#    - for example: str(translate(str.maketrans('','',string.punctuation)) : replace noting to nothing and remove punctuation which is to copy the whoel strings and delete punctuations in strings

# %%
import string
string.punctuation
# Out:
# '!"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~'

# %%
resturant=resturant.apply(lambda x: x.str.translate(str.maketrans('','',string.punctuation)))
resturant.head()
# Out:
#                        name                 address           city  \
# 0  ARNIE MORTONS OF CHICAGO   435 S LA CIENEGA BLVD    LOS ANGELES
# 1                 ARTS DELI      12224 VENTURA BLVD    STUDIO CITY
# 2              BELAIR HOTEL     701 STONE CANYON RD        BEL AIR
# 3                CAFE BIZOU      14016 VENTURA BLVD   SHERMAN OAKS
# 4                 CAMPANILE       624 S LA BREA AVE    LOS ANGELES
#
#           cuisine unique_id
# 0     STEAKHOUSES         0
# 1           DELIS         1
# 2     CALIFORNIAN         2
# 3   FRENCH BISTRO         3
# 4     CALIFORNIAN         4

# %%
data=data.apply(lambda x: x.str.translate(str.maketrans('','',string.punctuation)))
data.head()
# Out:
#                      name_2              address_2         city_2  \
# 0  ARNIE MORTONS OF CHICAGO   435 S LA CIENEGA BLV    LOS ANGELES
# 1         ARTS DELICATESSEN     12224 VENTURA BLVD    STUDIO CITY
# 2              HOTEL BELAIR    701 STONE CANYON RD        BEL AIR
# 3                CAFE BIZOU     14016 VENTURA BLVD   SHERMAN OAKS
# 4                 CAMPANILE      624 S LA BREA AVE    LOS ANGELES
#
#       cuisine_2 unique_id
# 0      AMERICAN         0
# 1      AMERICAN         1
# 2   CALIFORNIAN         2
# 3        FRENCH         3
# 4      AMERICAN         4

# %% [markdown]
# ### 2.3 Split column
# Goal: Split full street name to street number and street name to match separtely, since the same locations may have same street name while different street number sometimes from different
# data source.
#
# - series.str.split(pat = None,n=-1,expand= False):
#    - pat is the pattern to split. n is the number of split result. expand= True to expand the list to separate columns
#
#    - Conditional split: x.apply(lambda x: x.split() if condition else 0)
#
#    - If split a list return NAN: it may because the list been split already
#
#
# - series.replace(A,B): repalce A to B;
#    - if apply to column in dataframe A: use A.column.str.replace (same for all the str methods)
#
#
# - series.str.isdigit(): return True or False wether the string is digit
#
#
# - series.apply(pd.Series): change series type to DataFrame
#
#
# - regex: re.match == str.match; use ^[0-9] : define string starts with digit
#
#
# - get the first character of a column: resturant.address.str[0]; while if it is value of address, then no 'str' need: resturant.address[6][0]

# %%
## Can't split more, since [A,B] is the result after split
resturant.address.apply(lambda x: x.split(' ',2)[1:3] if x.find('[0-9]') else [0,x]).head()
# Out:
# 0    [435, S LA CIENEGA BLVD]
# 1       [12224, VENTURA BLVD]
# 2      [701, STONE CANYON RD]
# 3       [14016, VENTURA BLVD]
# 4        [624, S LA BREA AVE]
# Name: address, dtype: object

# %%
# split column into number and name if column startwith digit
resturant[['address_no','address_name']]=resturant.address.apply(lambda x: x.split(' ',2)[1:3] if x.replace(' ','')[0].isdigit() else [0,x]).apply(pd.Series)

# %%
resturant.head()
# Out:
#                        name                 address           city  \
# 0  ARNIE MORTONS OF CHICAGO   435 S LA CIENEGA BLVD    LOS ANGELES
# 1                 ARTS DELI      12224 VENTURA BLVD    STUDIO CITY
# 2              BELAIR HOTEL     701 STONE CANYON RD        BEL AIR
# 3                CAFE BIZOU      14016 VENTURA BLVD   SHERMAN OAKS
# 4                 CAMPANILE       624 S LA BREA AVE    LOS ANGELES
#
#           cuisine unique_id address_no       address_name
# 0     STEAKHOUSES         0        435  S LA CIENEGA BLVD
# 1           DELIS         1      12224       VENTURA BLVD
# 2     CALIFORNIAN         2        701    STONE CANYON RD
# 3   FRENCH BISTRO         3      14016       VENTURA BLVD
# 4     CALIFORNIAN         4        624      S LA BREA AVE

# %%
data[['address_no','address_name']]=data.address_2.apply(lambda x: x.split(' ',2)[1:3] if x.replace(' ','')[0].isdigit() else [0,x]).apply(pd.Series)

# %%
data.head()
# Out:
#                      name_2              address_2         city_2  \
# 0  ARNIE MORTONS OF CHICAGO   435 S LA CIENEGA BLV    LOS ANGELES
# 1         ARTS DELICATESSEN     12224 VENTURA BLVD    STUDIO CITY
# 2              HOTEL BELAIR    701 STONE CANYON RD        BEL AIR
# 3                CAFE BIZOU     14016 VENTURA BLVD   SHERMAN OAKS
# 4                 CAMPANILE      624 S LA BREA AVE    LOS ANGELES
#
#       cuisine_2 unique_id address_no      address_name
# 0      AMERICAN         0        435  S LA CIENEGA BLV
# 1      AMERICAN         1      12224      VENTURA BLVD
# 2   CALIFORNIAN         2        701   STONE CANYON RD
# 3        FRENCH         3      14016      VENTURA BLVD
# 4      AMERICAN         4        624     S LA BREA AVE

# %% [markdown]
# ## 3 Fuzzy match
#
# - fuzz.ratio(A,B): give the fuzz ratio for A and B
#
#
# - pd.merge(DF1,DF2, left_on='', right_on='', how='') merge two dataframe: how = inner, left, right  OR pd.merge(DF1,DF2, on='', how='') when mrge column names are same
#
#
# - astype(str): change data type
#
#
# - DF.reset_index(): reset the index to column or flatern the result from groupby

# %%
from fuzzywuzzy import fuzz

# %%
# match if the city name is same
result=pd.merge(resturant, data, left_on='city',right_on='city_2',how='left').apply(lambda x: x.astype(str))
result.head()
# Out:
#                        name                 address          city  \
# 0  ARNIE MORTONS OF CHICAGO   435 S LA CIENEGA BLVD   LOS ANGELES
# 1  ARNIE MORTONS OF CHICAGO   435 S LA CIENEGA BLVD   LOS ANGELES
# 2  ARNIE MORTONS OF CHICAGO   435 S LA CIENEGA BLVD   LOS ANGELES
# 3  ARNIE MORTONS OF CHICAGO   435 S LA CIENEGA BLVD   LOS ANGELES
# 4  ARNIE MORTONS OF CHICAGO   435 S LA CIENEGA BLVD   LOS ANGELES
#
#         cuisine unique_id_x address_no_x     address_name_x  \
# 0   STEAKHOUSES           0          435  S LA CIENEGA BLVD
# 1   STEAKHOUSES           0          435  S LA CIENEGA BLVD
# 2   STEAKHOUSES           0          435  S LA CIENEGA BLVD
# 3   STEAKHOUSES           0          435  S LA CIENEGA BLVD
# 4   STEAKHOUSES           0          435  S LA CIENEGA BLVD
#
#                      name_2              address_2        city_2  \
# 0  ARNIE MORTONS OF CHICAGO   435 S LA CIENEGA BLV   LOS ANGELES
# 1                 CAMPANILE      624 S LA BREA AVE   LOS ANGELES
# 2                    CITRUS       6703 MELROSE AVE   LOS ANGELES
# 3        GRILL ON THE ALLEY        9560 DAYTON WAY   LOS ANGELES
# 4          RESTAURANT KATSU   1972 N HILLHURST AVE   LOS ANGELES
#
#       cuisine_2 unique_id_y address_no_y    address_name_y
# 0      AMERICAN           0          435  S LA CIENEGA BLV
# 1      AMERICAN           4          624     S LA BREA AVE
# 2   CALIFORNIAN           6         6703       MELROSE AVE
# 3      AMERICAN           9         9560        DAYTON WAY
# 4         ASIAN          10         1972   N HILLHURST AVE

# %%
# calculate the fuzz ratio
result['address_name_score']=result.apply(lambda x: fuzz.ratio(x.address_name_x,x.address_name_y),axis=1)
result.head()
# Out:
#                        name                 address          city  \
# 0  ARNIE MORTONS OF CHICAGO   435 S LA CIENEGA BLVD   LOS ANGELES
# 1  ARNIE MORTONS OF CHICAGO   435 S LA CIENEGA BLVD   LOS ANGELES
# 2  ARNIE MORTONS OF CHICAGO   435 S LA CIENEGA BLVD   LOS ANGELES
# 3  ARNIE MORTONS OF CHICAGO   435 S LA CIENEGA BLVD   LOS ANGELES
# 4  ARNIE MORTONS OF CHICAGO   435 S LA CIENEGA BLVD   LOS ANGELES
#
#         cuisine unique_id_x address_no_x     address_name_x  \
# 0   STEAKHOUSES           0          435  S LA CIENEGA BLVD
# 1   STEAKHOUSES           0          435  S LA CIENEGA BLVD
# 2   STEAKHOUSES           0          435  S LA CIENEGA BLVD
# 3   STEAKHOUSES           0          435  S LA CIENEGA BLVD
# 4   STEAKHOUSES           0          435  S LA CIENEGA BLVD
#
#                      name_2              address_2        city_2  \
# 0  ARNIE MORTONS OF CHICAGO   435 S LA CIENEGA BLV   LOS ANGELES
# 1                 CAMPANILE      624 S LA BREA AVE   LOS ANGELES
# 2                    CITRUS       6703 MELROSE AVE   LOS ANGELES
# 3        GRILL ON THE ALLEY        9560 DAYTON WAY   LOS ANGELES
# 4          RESTAURANT KATSU   1972 N HILLHURST AVE   LOS ANGELES
#
#       cuisine_2 unique_id_y address_no_y    address_name_y  address_name_score
# 0      AMERICAN           0          435  S LA CIENEGA BLV                  97
# 1      AMERICAN           4          624     S LA BREA AVE                  60
# 2   CALIFORNIAN           6         6703       MELROSE AVE                  29
# 3      AMERICAN           9         9560        DAYTON WAY                  22
# 4         ASIAN          10         1972   N HILLHURST AVE                  31

# %%
## learned: reset_index(): reset the index as one column
## get the max score per name
max_address_name_score=result.groupby('name').address_name_score.max().reset_index().apply(pd.Series)
max_address_name_score.head()
# Out:
#              name  address_name_score
# 0         21 CLUB                  89
# 1         ABRUZZI                 100
# 2  ALAIN RONDELLI                 100
# 3            AQUA                 100
# 4         AQUAVIT                  89

# %%
## filter the highest score data
result1=pd.merge(result,max_address_name_score,on=['name','address_name_score'],how='inner')

# %%
# filter data if address number is same
result2=result1[result1['address_no_x']==result1['address_no_y']]
result2.head()
# Out:
#                        name                 address           city  \
# 0  ARNIE MORTONS OF CHICAGO   435 S LA CIENEGA BLVD    LOS ANGELES
# 1                 ARTS DELI      12224 VENTURA BLVD    STUDIO CITY
# 3              BELAIR HOTEL     701 STONE CANYON RD        BEL AIR
# 4                CAFE BIZOU      14016 VENTURA BLVD   SHERMAN OAKS
# 6                 CAMPANILE       624 S LA BREA AVE    LOS ANGELES
#
#           cuisine unique_id_x address_no_x     address_name_x  \
# 0     STEAKHOUSES           0          435  S LA CIENEGA BLVD
# 1           DELIS           1        12224       VENTURA BLVD
# 3     CALIFORNIAN           2          701    STONE CANYON RD
# 4   FRENCH BISTRO           3        14016       VENTURA BLVD
# 6     CALIFORNIAN           4          624      S LA BREA AVE
#
#                      name_2              address_2         city_2  \
# 0  ARNIE MORTONS OF CHICAGO   435 S LA CIENEGA BLV    LOS ANGELES
# 1         ARTS DELICATESSEN     12224 VENTURA BLVD    STUDIO CITY
# 3              HOTEL BELAIR    701 STONE CANYON RD        BEL AIR
# 4                CAFE BIZOU     14016 VENTURA BLVD   SHERMAN OAKS
# 6                 CAMPANILE      624 S LA BREA AVE    LOS ANGELES
#
#       cuisine_2 unique_id_y address_no_y    address_name_y  address_name_score
# 0      AMERICAN           0          435  S LA CIENEGA BLV                  97
# 1      AMERICAN           1        12224      VENTURA BLVD                 100
# 3   CALIFORNIAN           2          701   STONE CANYON RD                 100
# 4        FRENCH           3        14016      VENTURA BLVD                 100
# 6      AMERICAN           4          624     S LA BREA AVE                 100

# %% [markdown]
# ## 4 Check on the non-macthed
#
# - DF.column.isin(array): get data if the column value in arrays

# %%
name_list=resturant.name.unique()
matched_names=result2.name.unique()

# %%
non_matched=[i for i in name_list if i not in matched_names]

# %%
# Summary of the fuzzy match
print('Total distinct names:{}, number of names matched: {},number of names not_matched {}'.format(len(name_list),len(matched_names),len(non_matched)))
# Out:
# Total distinct names:112, number of names matched: 47,number of names not_matched 65

# %%
non_matched_data=resturant[resturant['name'].isin(non_matched)]
non_matched_data.head()
# Out:
#                    name                 address            city  \
# 7   FENIX AT THE ARGYLE        8358 SUNSET BLVD     W HOLLYWOOD
# 9            GRILL  THE         9560 DAYTON WAY   BEVERLY HILLS
# 10                KATSU      1972 HILLHURST AVE       LOS FELIZ
# 11           LORANGERIE   903 N LA CIENEGA BLVD     W HOLLYWOOD
# 13       LOCANDA VENETA         8638 W THIRD ST     LOS ANGELES
#
#                   cuisine unique_id address_no       address_name
# 7              FRENCH NEW         7       8358        SUNSET BLVD
# 9    AMERICAN TRADITIONAL         9       9560         DAYTON WAY
# 10               JAPANESE        10       1972      HILLHURST AVE
# 11         FRENCH CLASSIC        11        903  N LA CIENEGA BLVD
# 13                ITALIAN        13       8638         W THIRD ST

# %%
data.head()
# Out:
#                      name_2              address_2         city_2  \
# 0  ARNIE MORTONS OF CHICAGO   435 S LA CIENEGA BLV    LOS ANGELES
# 1         ARTS DELICATESSEN     12224 VENTURA BLVD    STUDIO CITY
# 2              HOTEL BELAIR    701 STONE CANYON RD        BEL AIR
# 3                CAFE BIZOU     14016 VENTURA BLVD   SHERMAN OAKS
# 4                 CAMPANILE      624 S LA BREA AVE    LOS ANGELES
#
#       cuisine_2 unique_id address_no      address_name
# 0      AMERICAN         0        435  S LA CIENEGA BLV
# 1      AMERICAN         1      12224      VENTURA BLVD
# 2   CALIFORNIAN         2        701   STONE CANYON RD
# 3        FRENCH         3      14016      VENTURA BLVD
# 4      AMERICAN         4        624     S LA BREA AVE

# %%
# use contains to manual check if data contains same string
data[data.address_2.str.contains('SUNSET')]
# Out:
#          name_2                                       address_2  \
# 7         FENIX                           8358 SUNSET BLVD WEST
# 136  GLADSTONES   4 FISH 17300 PACIFIC COAST HWY AT SUNSET BLVD
# 143        JOSS                                9255 SUNSET BLVD
# 145     LE DOME                                8720 SUNSET BLVD
# 550       DUKES                                8909 SUNSET BLVD
#
#                  city_2      cuisine_2 unique_id address_no  \
# 7             HOLLYWOOD       AMERICAN         7       8358
# 136   PACIFIC PALISADES       AMERICAN       136          4
# 143         LOS ANGELES          ASIAN       143       9255
# 145         LOS ANGELES         FRENCH       145       8720
# 550         W HOLLYWOOD   COFFEE SHOPS       551       8909
#
#                                     address_name
# 7                               SUNSET BLVD WEST
# 136  FISH 17300 PACIFIC COAST HWY AT SUNSET BLVD
# 143                                  SUNSET BLVD
# 145                                  SUNSET BLVD
# 550                                  SUNSET BLVD
